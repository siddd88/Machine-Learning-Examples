# %%
import numpy as np 
import get_data as gd 
from Logistic_Reg import LogisticRegressionGD
import matplotlib.pyplot as plt 
# %matplotlib inline

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(gd.X_train_std, gd.y_train)

gd.plot_decision_regions(gd.X_combined_std, gd.y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)

# %%
lr.predict_proba(gd.X_test_std[:3]).argmax(axis=1)
# Out:
# array([2, 0, 0], dtype=int64)

# %%
lr.predict_proba(gd.X_test_std[:3])
# Out:
# array([[  3.20136878e-08,   1.46953648e-01,   8.53046320e-01],
#        [  8.34428069e-01,   1.65571931e-01,   4.57896429e-12],
#        [  8.49182775e-01,   1.50817225e-01,   4.65678779e-13]])

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel='linear',C=1.0,random_state=1)

# %%
svm.fit(gd.X_combined_std,gd.y_combined)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
gd.plot_decision_regions(gd.X_combined_std, 
                      gd.y_combined,
                      classifier=svm, 
                      test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_11.png', dpi=300)
plt.show()
